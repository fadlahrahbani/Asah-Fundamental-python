# %% [markdown]
# # Fundamental Numpy

# %%
import numpy as np

# %%
#Perkalian matriks
a = np.array([1, 2, 3])
b = np.array([6, 7, 8])
print ("a x b =", a * b)
print ("a x 3 =", a*3)


#Notasi matematika
np.sum(a)
np.mean(a)
np.std(a)
np.sin(a)
# Out:
# a x b = [ 6 14 24]
# a x 3 = [3 6 9]
# array([0.84147098, 0.90929743, 0.14112001])

# %%
#linspace, range, logspace
np.arange(0, 5, 2)
# Out:
# array([0, 2, 4])

# %%
np.linspace(0, 10, 5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
np.logspace(-3, 3, 7)
# Out:
# array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])

# %%
np.random.rand(3, 2)
# Out:
# array([[0.58358536, 0.69066176],
#        [0.72598654, 0.72086488],
#        [0.43226428, 0.97241758]])

# %%
state = np.random.RandomState(42)
state.rand(3)
# Out:
# array([0.37454012, 0.95071431, 0.73199394])

# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('C:/Users/ASUS/Downloads/cereal.csv')
dataset
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
contoh_data = { "Nama": ["Prabowo", "Teddy", "Gibran"], "IQ": [16, 30, 5]}
pd.DataFrame(contoh_data)
# Out:
#       Nama  IQ
# 0  Prabowo  16
# 1    Teddy  30
# 2   Gibran   5
